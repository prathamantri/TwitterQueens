# %%
# HYPOTHESYS
# We expect that mentions of Trumps will have 50/50 positive and negative
# We expect more positive tweets volume from republican states
# We expect Trump's tweets to be majority negative
# What are the main keywords Trump uses and what are the sentiment about those subjects

# %%
# import dependencies 
import os
import pandas as pd
from matplotlib import pyplot as plt
import time
import csv
import json
import requests
from config import api_key, api_secret_key
import gmaps
import re 
import twitter
import tweepy 
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from textblob import TextBlob 
import base64


# Access maps with unique API key
# gmaps.configure(api_key=gkey)

# url for API

# url = 'https://api.twitter.com/1.1/search/tweets.json'

# # Store a the twitter handle mentions we will use

# handle = '@realDonaldTrump'

# Filter the request for  "geo_enabled": true, language to be only english (lang=en), restrict by region = United Sates
# Reference the url to request the api data, but not going over the 
# request limit per second (max_number_of_requests = 180 per 15 min)
# https://towardsdatascience.com/creating-the-twitter-sentiment-analysis-program-in-python-with-naive-bayes-classification-672e5589a7ed

# convert to JSON object 

# Create a dictionary with the data we need:
            
# print the request to get an idea of the set

# Reference the url for the sentiment analysis code 'https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/''

# %%
# Authenticate and Make the first API request

client_key = api_key
client_secret = api_secret_key

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

auth_resp.json().keys()

access_token = auth_resp.json()['access_token']

search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

# %%
# Adjust parameters for test run
from collections import defaultdict 
search_params = {
    'q': '@realDonaldTrump',
    'lang': 'en',
    'count': 450
}

# Date(created_at), Location (geocode), , Tweet (text), (user_mentions),  (hashtags),
#(symbols), user id ("user": id, id_string)
# followers volume (followers_count), friends count (friends_count), (favourites_count)
# (retweet_count), (retweeted), (possibly_sensitive), 


search_url = '{}1.1/search/tweets.json'.format(base_url)


search_resp = requests.get(search_url, headers=search_headers, params=search_params)

tweet_data = search_resp.json()

tweet_data_filter = defaultdict(list)

statuses = tweet_data['statuses']
processed_tweet_ids = set()

# %%
for status in statuses:
    tweet_id = status['id_str']
    if tweet_id in processed_tweet_ids:
        continue
    
    processed_tweet_ids.add(tweet_id)

    tweet_data_filter["UserName"].append(status['user']['screen_name'])
    tweet_data_filter["text"].append(status['text'])
    tweet_data_filter["created_at"].append(status['created_at'])
    tweet_data_filter["followers_count"].append(status['user']['followers_count'])
    tweet_data_filter["retweet_count"].append(status['retweet_count'])
    tweet_data_filter["favorite_count"].append(status['favorite_count'])
    tweet_data_filter["TweetID"].append(tweet_id)
    tweet_data_filter["Retweeted"].append(status['retweeted'])
    tweet_data_filter["UserID"].append(status['user']['id_str'])
    tweet_data_filter["language"].append(status['user']['lang'])
    tweet_data_filter['verified'].append(status['user']['verified'])

tweet_data_filter_pdf = pd.DataFrame(tweet_data_filter)
tweet_data_filter_pdf
# Out:
#            UserName                                               text  \
# 0      JudyBoomtown  RT @charliekirk11: The @realDonaldTrump econom...
# 1         blufftalk  RT @eugenegu: @realDonaldTrump Healthcare is a...
# 2          IP_Sidhu  RT @The_Trump_Train: @realDonaldTrump Not one ...
# 71   TheDilshadKhan  RT @realDonaldTrump: ....invited Megan or the ...
# 72  RoseHelenFritz2  @KatrinaPierson @realDonaldTrump Says the pro ...
# 73       SadcryingC  RT @GOPChairwoman: This isn’t the vote of conf...
# 74  MeShell53788768  @realDonaldTrump Too bad you're not still capa...
# 75      mikrozonrox  RT @meganrapino: @realDonaldTrump  ? Are you r...
# 76          remhamf  RT @tedlieu: My view is that the winner of a P...
# 77        suski8517  @LindseyGrahamSC @realDonaldTrump WTAF is wron...
# 78        virgo6776  @WayneDupreeShow @realDonaldTrump Of course ea...
# 79   UltimateBiebur  RT @eugenegu: @realDonaldTrump Healthcare is a...
# 80         drtimber  @Topcat03297023 @realDonaldTrump Legal vs Ille...
# 81  Terriandfriendz  RT @thedilleyshow: Dear Democrats...\n\n- Pres...
# 82  gregproughyaho1  RT @ProudResister: Night 1 = @EWarren\n\nNight...
# 83   RealLonestarTX  @ChatByCC @realDonaldTrump It can be asked. Th...
# 84    Mr_SethRankin  RT @Ant_v1_: @mariaxarellano @angelitaaaxo Don...
#
#                         created_at  followers_count  retweet_count  \
# 0   Fri Jun 28 04:25:37 +0000 2019              145           1384
# 1   Fri Jun 28 04:25:37 +0000 2019             1280           1145
# 2   Fri Jun 28 04:25:37 +0000 2019              449           1725
# 3   Fri Jun 28 04:25:37 +0000 2019              522              0
# 4   Fri Jun 28 04:25:37 +0000 2019              241            242
# 5   Fri Jun 28 04:25:37 +0000 2019             2211           2473
# 6   Fri Jun 28 04:25:37 +0000 2019              301            368
# 7   Fri Jun 28 04:25:36 +0000 2019              362          19425
# 8   Fri Jun 28 04:25:36 +0000 2019               78              0
# 9   Fri Jun 28 04:25:36 +0000 2019              987              0
# 10  Fri Jun 28 04:25:36 +0000 2019              228            196
# 11  Fri Jun 28 04:25:36 +0000 2019              655           3049
# 12  Fri Jun 28 04:25:36 +0000 2019              329             17
# 13  Fri Jun 28 04:25:36 +0000 2019               98              0
# 14  Fri Jun 28 04:25:36 +0000 2019             2368            526
# 15  Fri Jun 28 04:25:36 +0000 2019              185           6590
# 16  Fri Jun 28 04:25:35 +0000 2019                0              1
# 17  Fri Jun 28 04:25:35 +0000 2019              156           6492
# 18  Fri Jun 28 04:25:35 +0000 2019              268              0
# 19  Fri Jun 28 04:25:35 +0000 2019                7              0
# 20  Fri Jun 28 04:25:35 +0000 2019              372          34104
# 21  Fri Jun 28 04:25:35 +0000 2019              217             23
# 22  Fri Jun 28 04:25:35 +0000 2019              616            320
# 23  Fri Jun 28 04:25:35 +0000 2019              199          34104
# 24  Fri Jun 28 04:25:35 +0000 2019              155              0
# 25  Fri Jun 28 04:25:35 +0000 2019             3000              1
# 26  Fri Jun 28 04:25:35 +0000 2019               10              0
# 27  Fri Jun 28 04:25:35 +0000 2019                2              0
# 28  Fri Jun 28 04:25:34 +0000 2019              445             36
# 29  Fri Jun 28 04:25:34 +0000 2019              210              0
# ..                             ...              ...            ...
# 55  Fri Jun 28 04:25:31 +0000 2019                4           3480
# 56  Fri Jun 28 04:25:31 +0000 2019              950            526
# 57  Fri Jun 28 04:25:31 +0000 2019              423            196
# 58               0  1144461801414746113      False   713107684581588994
# 59               0  1144461800894681088      False   946028271334051841
# 60               0  1144461800429084673      False             22990834
# 61               0  1144461799942586368      False           3195487010
# 62               0  1144461799430840322      False           3312056592
# 63               0  1144461799401504771      False   975099100915003392
# 64               0  1144461798986305537      False   906631996637560832
# 65               0  1144461798873026560      False   882073200032714752
# 66               0  1144461798260662273      False   820129376494723072
# 67               0  1144461797870596096      False           2857981888
# 68               1  1144461797845422090      False   821481932802301953
# 69               0  1144461797648244736      False  1054101341524549632
# 70               0  1144461797400825860      False   959615712867176448
# 71               0  1144461796411002880      False   817469397732388865
# 72               0  1144461796272570369      False   833864468379504640
# 73               0  1144461796171870208      False  1128033308254752768
# 74               0  1144461795156885505      False  1117603727697940480
# 75               0  1144461794976530432      False  1094418155739308032
# 76               0  1144461794976473089      False             46053827
# 77               0  1144461794812911618      False           3272030330
# 78               0  1144461794464825345      False           3167535227
# 79               0  1144461794376687617      False            336546804
# 80               0  1144461793860845569      False            377713805
# 81               0  1144461791579086848      False   713080611284586496
# 82               0  1144461791092547584      False   994713337974816768
# 83               0  1144461790291451904      False  1085388422062264320
# 84               0  1144461789293244419      False           3116485317
#
#    language  verified
# 0        en     False
# 1        en     False
# 2        en     False
# 3        en     False
# 4        en     False
# 5        en     False
# 6        en     False
# 7        en     False
# 8        en     False
# 9        en     False
# 10       en     False
# 11       en     False
# 12       en     False
# 13       en     False
# 14       en     False
# 15       en     False
# 16       en     False
# 17       en     False
# 18       en     False
# 19       en     False
# 20       en     False
# 21       en     False
# 22       en     False
# 23       en     False
# 24       en     False
# 25       en     False
# 26       en     False
# 27       en     False
# 28       en     False
# 29       en     False
# ..      ...       ...
# 55       en     False
# 56       en     False
# 57       en     False
# 58       en     False
# 59       en     False
# 60       en     False
# 61       en     False
# 62       en     False
# 63       en     False
# 64       en     False
# 65       en     False
# 66       en     False
# 67       en     False
# 68       en     False
# 69       en     False
# 70       en     False
# 71       en     False
# 72       en     False
# 73       en     False
# 74       en     False
# 75       ko     False
# 76       en     False
# 77       en     False
# 78       en     False
# 79       en     False
# 80       en     False
# 81       en     False
# 82       en     False
# 83       en     False
# 84       en     False
#
# [85 rows x 11 columns]

# %%
tweet_data_filter_pdf.to_csv("TweetFile1.csv", index=False, header=True)

# %%
# Adjust parameters for test run
from collections import defaultdict 

trump_search_params = {
    'screen_name': 'realDonaldTrump',
    'count': 1000
}


user_url = '{}1.1/statuses/user_timeline.json'.format(base_url)


search_resp2 = requests.get(user_url, headers=search_headers, params=trump_search_params)

trump_tweet_data = search_resp2.json()

trump_tweet_data_filter = defaultdict(list)

processed_trump_tweet_ids = set()

# trump_tweet_data

# %%
for tweet in trump_tweet_data:
    trump_tweet_id = tweet['id_str']
    if trump_tweet_id in processed_tweet_ids:
        continue
        
    processed_trump_tweet_ids.add(trump_tweet_id)
    
    trump_tweet_data_filter["UserName"].append(tweet['user']['screen_name'])
    trump_tweet_data_filter["text"].append(tweet['text'])
    trump_tweet_data_filter["created_at"].append(tweet['created_at'])
    trump_tweet_data_filter["followers_count"].append(tweet['user']['followers_count'])
    trump_tweet_data_filter["retweet_count"].append(tweet['retweet_count'])
    trump_tweet_data_filter["favorite_count"].append(tweet['favorite_count'])
    trump_tweet_data_filter["TweetID"].append(tweet['id_str'])
    trump_tweet_data_filter["Retweeted"].append(tweet['retweeted'])
    trump_tweet_data_filter["UserID"].append(tweet['user']['id_str'])
    trump_tweet_data_filter["language"].append(tweet['user']['lang'])
    trump_tweet_data_filter['verified'].append(tweet['user']['verified'])


trump_data_filter_pdf = pd.DataFrame(trump_tweet_data_filter)

trump_data_filter_pdf
# Out:
#              UserName                                               text  \
# 0     realDonaldTrump  All Democrats just raised their hands for givi...
# 1     realDonaldTrump  Great to be back in Japan for the #G20OsakaSum...
# 2     realDonaldTrump  Bipartisan Humanitarian Aid Bill for the South...
# 3     realDonaldTrump  .....United States Supreme Court is given addi...
# 4     realDonaldTrump  Seems totally ridiculous that our government, ...
# 5     realDonaldTrump      Thank you! #G20Summit https://t.co/28Y5rPE3BE
# 6     realDonaldTrump  Thank you @MSNBC, real professionals! @chuckto...
# 7     realDonaldTrump  I look forward to speaking with Prime Minister...
# 8     realDonaldTrump                            https://t.co/JDS4zVfyBe
# 9     realDonaldTrump  Just stopped in Alaska and said hello to our G...
# 10    realDonaldTrump  .@NBCNews and @MSNBC should be ashamed of them...
# 11    realDonaldTrump                                            BORING!
# 12    realDonaldTrump  These flyers depict Australia’s policy on Ille...
# 13    realDonaldTrump  .@ByronYork: “What now, for those who denied a...
# 14    realDonaldTrump  ....They came to me asking for help, and I got...
# 15    realDonaldTrump  Ever since the passage of the Super Predator C...
# 16    realDonaldTrump  For tonight’s #DemDebate, be sure to follow @T...
# 17    realDonaldTrump  ....and all of the others who have leaked, lie...
# 18    realDonaldTrump  Why aren’t the Democrats in the House calling ...
# 19    realDonaldTrump  The Republican Senate just passed bipartisan h...
# 20    realDonaldTrump  ....No Collusion, No Obstruction! Robert Muell...
# 21    realDonaldTrump  According to Fake News (and low ratings) @CNN,...
# 22    realDonaldTrump  “I have been in office for many years, the Mil...
# 23    realDonaldTrump                            https://t.co/mudnBtvWO1
# 24    realDonaldTrump  The Democrats would save many lives if they wo...
# 25    realDonaldTrump  Just departed for the #G20 Summit in Osaka, Ja...
# 26    realDonaldTrump  The Democrats should change the Loopholes and ...
# 27    realDonaldTrump  It was my great honor to speak at the Faith &a...
# 28    realDonaldTrump  ....invited Megan or the team, but I am now in...
# 29    realDonaldTrump  ....in our Country’s history, and the poverty ...
# ...               ...                                                ...
# 7570  realDonaldTrump  .....ALSO, NOT TRUE! Anything goes with our Co...
# 7571  realDonaldTrump  Do you believe that the Failing New York Times...
# 7572  realDonaldTrump  .....the first 2 1/2 years of his Presidency, ...
# 7573  realDonaldTrump  ....misleading in that I personally spent only...
# 7574  realDonaldTrump  I enjoyed my interview with @GStephanopoulos o...
# 7575  realDonaldTrump  He is a national disgrace who is destroying th...
# 7576  realDonaldTrump  RT @PressSec: I am blessed and forever gratefu...
# 7577  realDonaldTrump  The Corrupt News Media is totally out of contr...
# 7578  realDonaldTrump                            https://t.co/jlmmOCxk9H
# 7579  realDonaldTrump  LONDON needs a new mayor ASAP. Khan is a disas...
# 7580  realDonaldTrump  Thank you Steve &amp; family! https://t.co/1lg...
# 7581  realDonaldTrump  RT @SteveScalise: For weeks Republicans have a...
# 7582  realDonaldTrump  The Trump Economy is setting records, and has ...
# 7583  realDonaldTrump  “President Trump to launch 2020 Campaign in Fl...
# 7584  realDonaldTrump  All in for Senator Steve Daines as he proposes...
# 7585  realDonaldTrump  Despite the Greatest Presidential Harassment o...
# 7586  realDonaldTrump  RT @DanScavino: Dems will keep their (embarras...
# 7587  realDonaldTrump  RT @DanScavino: President @realDonaldTrump sta...
# 7588  realDonaldTrump  RT @DanScavino: .@realDonaldTrump stops by for...
# 7589  realDonaldTrump  RT @DanScavino: As the worst Mayor in the hist...
# 7590  realDonaldTrump            RT @DanScavino: https://t.co/85xnJ7mpp7
# 7591  realDonaldTrump  RT @DanScavino: NEVER GETS OLD....\nhttps://t....
# 7592  realDonaldTrump  RT @WhiteHouse: NEXT UP: President @realDonald...
# 7593  realDonaldTrump  RT @TeamTrump: Today, President @realDonaldTru...
# 7594  realDonaldTrump  RT @CLewandowski_: Great to see a strong showi...
# 7595  realDonaldTrump  “With over a 50% Approval Rating at this point...
# 7596  realDonaldTrump  “The latest Polls find 51% of Americans approv...
# 7597  realDonaldTrump  RT @WhiteHouse: Opioid addiction can happen to...
# 7598  realDonaldTrump  RT @FLOTUS: We must never forget the lives los...
# 7599  realDonaldTrump  RT @FLOTUS: Great to welcome back President Du...
#
#                           created_at  followers_count  retweet_count  \
# 0     Fri Jun 28 01:37:04 +0000 2019         61443823          33299
# 1     Fri Jun 28 00:46:37 +0000 2019         61443823           7823
# 2     Thu Jun 27 22:22:39 +0000 2019         61443823          17354
# 3     Thu Jun 27 17:37:32 +0000 2019         61443823          20285
# 4     Thu Jun 27 17:37:32 +0000 2019         61443823          22515
# 5     Thu Jun 27 13:28:46 +0000 2019         61443823          12035
# 6     Thu Jun 27 09:36:39 +0000 2019         61443823          39006
# 7     Thu Jun 27 03:47:05 +0000 2019         61443823          21300
# 8     Thu Jun 27 02:40:04 +0000 2019         61443823          33978
# 9     Thu Jun 27 02:33:50 +0000 2019         61443823          22372
# 10    Thu Jun 27 02:06:51 +0000 2019         61443823          23676
# 11    Thu Jun 27 01:35:55 +0000 2019         61443823          73060
# 12    Thu Jun 27 00:02:08 +0000 2019         61443823          20108
# 13    Wed Jun 26 23:52:03 +0000 2019         61443823          12577
# 14    Wed Jun 26 23:46:05 +0000 2019         61443823          12841
# 15    Wed Jun 26 23:46:04 +0000 2019         61443823          15119
# 16    Wed Jun 26 23:14:52 +0000 2019         61443823          16745
# 17    Wed Jun 26 22:47:43 +0000 2019         61443823          16826
# 18    Wed Jun 26 22:47:42 +0000 2019         61443823          19205
# 19    Wed Jun 26 21:47:40 +0000 2019         61443823          16625
# 20    Wed Jun 26 21:46:46 +0000 2019         61443823          12030
# 21    Wed Jun 26 21:46:45 +0000 2019         61443823          14020
# 22    Wed Jun 26 21:17:54 +0000 2019         61443823          15744
# 23    Wed Jun 26 20:31:31 +0000 2019         61443823          10712
# 24    Wed Jun 26 20:24:00 +0000 2019         61443823          15010
# 25    Wed Jun 26 19:13:22 +0000 2019         61443823          10853
# 18             77345  1144014401164337152      False  25073877     None
# 19             61349  1143999292538937344      False  25073877     None
# 20             60881  1143999067300610048      False  25073877     None
# 21             68575  1143999063613853696      False  25073877     None
# 22             78680  1143991802405376000      False  25073877     None
# 23             36392  1143980127161708544      False  25073877     None
# 24             63485  1143978235878789120      False  25073877     None
# 25             54259  1143960463442530304      False  25073877     None
# 26             68814  1143948712684576768      False  25073877     None
# 27             48020  1143925292492365824      False  25073877     None
# 28            127575  1143892329582997505      False  25073877     None
# 29             90716  1143892328236687361      False  25073877     None
# ...              ...                  ...        ...       ...      ...
# 7570           79115  1140065304019644427      False  25073877     None
# 7571           87837  1140065300186128384      False  25073877     None
# 7572           83635  1140059246781968385      False  25073877     None
# 7573           74280  1140059245456633858      False  25073877     None
# 7574           84550  1140059243518865408      False  25073877     None
# 7575           91056  1140035545738989569      False  25073877     None
# 7576               0  1140032992074768384      False  25073877     None
# 7577          104758  1139971974854258688      False  25073877     None
# 7578           36392  1139968481921851392      False  25073877     None
# 7579          110825  1139967706424369152      False  25073877     None
# 7580           44552  1139967059503329282      False  25073877     None
# 7581               0  1139966959716577280      False  25073877     None
# 7582           81174  1139891393252474880      False  25073877     None
# 7583           59873  1139879172170539009      False  25073877     None
# 7584           84741  1139878112701927424      False  25073877     None
# 7585           82280  1139866464599642112      False  25073877     None
# 7586               0  1139862983553757184      False  25073877     None
# 7587               0  1139862755383500800      False  25073877     None
# 7588               0  1139862693450436608      False  25073877     None
# 7589               0  1139862587963858944      False  25073877     None
# 7590               0  1139862449556000768      False  25073877     None
# 7591               0  1139862388180758528      False  25073877     None
# 7592               0  1139862264511717376      False  25073877     None
# 7593               0  1139861914564157441      False  25073877     None
# 7594               0  1139861610196066304      False  25073877     None
# 7595           77057  1139861307002368000      False  25073877     None
# 7596           63751  1139859489832820737      False  25073877     None
# 7597               0  1139857792569872384      False  25073877     None
# 7598               0  1139857623271071747      False  25073877     None
# 7599               0  1139857560792653824      False  25073877     None
#
#       verified
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# ...        ...
# 7570      True
# 7571      True
# 7572      True
# 7573      True
# 7574      True
# 7575      True
# 7576      True
# 7577      True
# 7578      True
# 7579      True
# 7580      True
# 7581      True
# 7582      True
# 7583      True
# 7584      True
# 7585      True
# 7586      True
# 7587      True
# 7588      True
# 7589      True
# 7590      True
# 7591      True
# 7592      True
# 7593      True
# 7594      True
# 7595      True
# 7596      True
# 7597      True
# 7598      True
# 7599      True
#
# [7600 rows x 11 columns]

# %%
trump_data_filter_pdf.to_csv("TrumpFile1.csv", index=False, header=True)

# %%
# DATA CLEANING

# %%
# VISUALIZATION REQUEIREMENTS - 6-8

# What is the distribution of sentiment (positive/negative/neutral) per mention of handle?
# Piechart/bar chart per handle mention

# How many (positive/negative/neutral) retweets?


# Scatter plot - size of bubles is number of followers

# Most commom used words by Trump - top keywords
# Use of exclamation points
# Use of Caps lock?
# Emoji symbols he uses

# Sentiment analysis of Trump Tweets
# Sentiment analysis of his tweets for top 5 keyqords he uses (sort and select top 5 based on total count)


# Scatter plot of Trumps tweets colored by sentiment

# Save png versions of our visuals

# %%
# OBSERVATIONS/TRENDS

# Implications - can we predict if he will be elected or not
